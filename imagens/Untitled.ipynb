# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("/home/nicoli/github/ssd_keras/dataset/csv/imdb_csv/imdb_clean.csv", index_col=0)

# %%
df.groupby('celeb_id').size().sort_values(ascending=False).head()
# Out:
# celeb_id
# 16349    38
# 3855     34
# 5429     29
# 13498    29
# 2686     28
# dtype: int64

# %%
df_deniro = df.groupby('celeb_id').get_group(16349).sort_values('photo_taken', ascending=False).reset_index(drop=True)

# %%
df_deniro.loc[0, 'age']
# Out:
# 71.0

# %%
from PIL import Image

# %%
deniro = Image.open('/home/nicoli/github/ssd_keras/dataset/'+ df_deniro.loc[3, 'full_path'])
deniro = deniro.resize((224,224))

plt.imshow(deniro)
plt.axis('off')

deniro.save("deniro3.png")
# Out:
# (-0.5, 223.5, 223.5, -0.5)

# %%
import numpy as np

deniro = np.array(deniro)

# %%
deniro = np.resize(deniro, (224,224,3))

# %%
plt.imshow(deniro)

# %%
deniro.shape
# Out:
# (501, 500, 3)

# %%
plt.imsave()
